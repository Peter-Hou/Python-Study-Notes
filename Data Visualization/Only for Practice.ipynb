# %%
from matplotlib import pyplot as plt

# %%
figure = plt.figure(figsize = (10, 8))

rows = [10000]
rows.extend([i * 100000 for i in range(1, 7)])

avg_time = [180, 85, 84, 83, 86, 85.5, 85]

plt.plot(rows, avg_time, color = 'blue')

row2 = [i * 100000 for i in range(4, 11)]
avg_time = [82, 81, 80, 79.5, 79, 80, 80]

plt.plot(row2, avg_time, color = 'orange')

row3 = [i * 100000 for i in range(7, 11)]

avg_time = [79, 80, 81, 81.5]

plt.plot(row3, avg_time, color = 'grey')

row4 = [i * 100000 for i in range(8, 11)]

avg_time = [85, 82, 78.5]

plt.plot(row4, avg_time, color = 'green')

legend = plt.legend(['10485760', '20971520', '31457280', '52428800', '62914560'])

legend.set_title("Default Max Buffer Size (byte)")
plt.xlabel('Default Max Buffer Rows')

plt.ylabel("Sum of Average Running Times (sec)")

ax = plt.subplot()

#rows = [10000]
row = [i * 100000 for i in range(0, 11)]
row8 = [i * 100000 for i in range(1, 11)]


ax.set_xticks(row)

row = [10000]
row.extend(row8)
ax.set_xticklabels(row, rotation = 30)

plt.savefig('test with buffer row, size parameter.png')
plt.show()
